# %%
#It's iceland national flag
import numpy as np
from PIL import Image
flag = np.zeros((600,900,3), dtype='uint8')
for x in range(900):
    for y in range(600):
        flag[y, x, 0] =0
        flag[y, x, 1] = 0
        flag[y, x, 2] = 205
        flag[:,200:400]=255
        flag[250:400]=255
        flag[:,250:350,]=(255,0,0)
        flag[287:363,]=(255,0,0)
Image.fromarray(flag)
# Out:
# <PIL.Image.Image image mode=RGB size=900x600 at 0x20AABB8B730>
